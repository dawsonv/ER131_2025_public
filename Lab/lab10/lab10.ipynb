# %% [markdown]
# # Lab 10
#
# Welcome to the tenth and final lab of the semester! In this lab, we'll use machine learning to predict structural damage to California homes affected by wildfires. To do this, we'll use a subset of the CAL FIRE Damage Inspection (DINS) dataset.

# %% [markdown]
# Before you turn this problem in, make sure everything runs as expected. In the menubar, select **Kernel** $\rightarrow$ **Restart Kernel and Run All Cells...**. If you do not run a specific cell, you will not receive credit for that question.
#
# Make sure you fill in any place that says `YOUR CODE HERE` or "YOUR ANSWER HERE", as well as your name and collaborators below:

# %%
NAME = "" # put your full name here
COLLABORATORS = [] # list anyone you collaborated with on this workbook

# %% [markdown]
# ---

# %% [markdown]
# ## Setup

# %%
import numpy as np
import pandas as pd
import geopandas as gpd

# %% [markdown]
# ----
# ## DINS Data
#
# To get started, let's read in the dataset for this lab. We'll be using the [CAL FIRE Damage Inspection (DINS) data](https://data.ca.gov/dataset/cal-fire-damage-inspection-dins-data). The DINS dataset contains site inspection data for every fire-affected structure in California, including stucture chatacteristics and a damage classification. Because the raw DINS data is relatively large, we'll only be looking at data from a single fire: the [2020 Glass Fire](https://en.wikipedia.org/wiki/Glass_Fire).
#
# **Question 1 (1pt):** Load in the .geojson file in the "data" folder and save it to a dataframe `dins`. You may find it helpful to look at a prior lab notebook where we used GeoPandas to read a file with spatial data.

# %%
# YOUR CODE HERE
dins = ...

# %% [markdown]
# Now let's get familiar with the dataset. To start, let's take a look at the distribution of our categoricl target variable: `DAMAGE`.
#
# **Question 2 (1pt):** Using `value_counts`, count the number of structures that fall into each `DAMAGE` category.

# %%
# YOUR CODE HERE
...

# %% [markdown]
# Since "No Damage" and "Destroyed (>50%)" are by far the most common values in the `DAMAGE` column, we'll focus on binary prediction using just those two labels.
#
# **Question 3 (1pt):** Using the method of your choice, drop every row where `DAMAGE` takes a value that is not either "No Damage" or "Destroyed (>50%)". Hint: you might want to use `loc` or `query`.

# %%
# YOUR CODE HERE
...

# %% [markdown]
# **Question 4 (2pt):** Now make a quick map to illustrate the spatial distribution of structure damage. Do you notice anything about the plot?

# %%
# YOUR CODE HERE
...

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# Now that we have a basic understanding of our target, we'll take a closer look at the features. First, we'll take a look at the column names.

# %%
dins.columns

# %% [markdown]
# **Question 5 (2pt):** Pick two columns to look at more closely. Do some simple exploratory data analysis on those columns. Show your work. Feel free to add more code cells if you want.

# %%
# YOUR CODE HERE
...

# %% [markdown]
# ----
# ## Feature Engineering and the Train-Test Split
#
# For now, we'll use the columns in the list below as our features.

# %%
x_cols = [
    'DEFENSIVEACTIONS', 'STRUCTURETYPE','STRUCTURECATEGORY', 'ROOFCONSTRUCTION', 
    'EAVES', 'VENTSCREEN', 'EXTERIORSIDING', 'WINDOWPANE',
    'DECKPORCHONGRADE', 'DECKPORCHELEVATED','PATIOCOVERCARPORT', 'FENCEATTACHEDTOSTRUCTURE'
]

# %% [markdown]
# **Question 6 (2pt):** Produce a dataframe of features called `X` and a dataframe of targets called `y`. The feature dataframe should contain data from the features listed in `x_cols` above. Because these features are all categorical, you shouold convert them to dummy variables. Finally, so we don't loose any observations, NA values should be represented as their own dummy column.

# %%
# YOUR CODE HERE
X = ...
y = ...

# %%
assert X.shape == (4480, 85)
assert len(y) == 4480

# %% [markdown]
# **Question 7 (2pt):** Using `X` and `y` from the previous step, do an 80/20 train test split. Set `random_state` to 123 and stratify the split on `y` to make sure that we see an equal proportion of `Destroyed` and `No Damage` buildings in both the train and test set.

# %%
# YOUR CODE HERE
from sklearn.model_selection import train_test_split

...

# %% [markdown]
# -------
# ## Modeling

# %% [markdown]
# We're finally ready to start modeling! First we'll use kNN to predict predict damage as a function of structural building chatacteristics.
#
# **Question 8 (2pt):** Initialize a kNN model. Use $k=5$ neighbors and [Hamming discance](https://en.wikipedia.org/wiki/Hamming_distance) rather than Euclidian distance. Evaluate the model using 10-fold cross-validation (using the procedure outlined in the [sklearn documentation](https://scikit-learn.org/stable/modules/cross_validation.html)).

# %%
# YOUR CODE HERE
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score

# initialize the model
knn = ...

# Run 10-fold cross-validation
cv_score = ...
print(cv_score)

# %% [markdown]
# Impressive start! Let's see how a decision tree classifier compares.
#
# **Question 9 (2pt):** Fit a single decision tree classifier to the data using default parameters, then evaluate your model using 10-fold cross validation. How does this model perform relative to the kNN model from the previous question?

# %%
# SOLUTION
from sklearn.tree import DecisionTreeClassifier

# initialize the model
tree = ...

# Run 10-fold cross-validation
cv_score = ...
print(cv_score)

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# **Question 10 (2pt):** Is there a value of the hyperparameter `max_depth` at which the decision tree classifier performs better than kNN?

# %%
# YOUR CODE HERE
# initialize the model with your choice of max_depth
tree = ...

# Run 10-fold cross-validation
cv_score = ...
print(cv_score)

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# **Question 11 (2pt):** Take a look at the [Supervised Learning section](https://scikit-learn.org/stable/supervised_learning.html) of the sklearn documentation. Try to find a model that out-performs both kNN and the decision tree.

# %%
# YOUR CODE HERE
...

# %% [markdown]
# **Question 12 (4pt):** Pick a model from the past three questions, train it on the entire training set, and make predictions on the test set. Then report the classification error for both the training and test set. How to the train and test error compare to your estimates from k-fold CV?

# %%
# YOUR CODE HERE
...

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# **Question 13 (4pt):** Using your test set predictions from the previous question, produce a confusion matrix. Use the confustion matrix to compute precision, recall, false positive rate, and false negative rate.

# %%
# YOUR CODE HERE
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test_pred, y_test)
tn, fp, fn, tp = cm.ravel().tolist()

precision = ...
recall = ...
fpr = ...
fnr = ...

print('Precision: {}'.format(precision))
print('Recall: {}'.format(recall))
print('False Positive Rate: {}'.format(fpr))
print('False Negative Rate: {}'.format(fnr))

# %% [markdown]
# **Question 14 (2pt):** Examine the result from the previous question. How does your model handle the tradeoff between precision and recall, or alternatively, between false positives and false negatives? How might this impact resource allocation decisions?

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# **Question 15 (2pt):** An insurance company wants to use the model you just made to price wildfire risk across the entire western US. Is this a good idea? Why or why not?

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# ----
#
# ## Submission
#
# Congrats, you're done with Lab 10!
#
# In order to turn in this assignment, go to the toolbar and click **File** -> **Download as** -> **HTML**. Submit the downloaded file through bCourses.
#
# ----
